# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("../newCourse/mizban_orders.csv",index_col=0)

value_count= df["orders"].value_counts()

df['orders'].astype(float)

df.info()

df["value_count"] = df["orders"].map(value_count)

df.head(10)
# Out:
# <class 'pandas.DataFrame'>
# Index: 59 entries, 2026-01-01 to 2026-02-28
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   weekday           59 non-null     int64
#  1   is_weekend        59 non-null     int64
#  2   orders            59 non-null     int64
#  3   completed_orders  59 non-null     int64
#  4   canceled_orders   59 non-null     int64
#  5   active_users      59 non-null     int64
#  6   restaurants       59 non-null     int64
#  7   promotion         59 non-null     int64
# dtypes: int64(8)
# memory usage: 4.1+ KB
#             weekday  is_weekend  orders  completed_orders  canceled_orders  \
# date
# 2026-01-01        4           0      95                88                7
# 2026-01-02        5           0     110               101                9
# 2026-01-03        6           1     150               132               18
# 2026-01-04        7           1     165               145               20
# 2026-01-05        1           0      90                83                7
# 2026-01-06        2           0     100                92                8
# 2026-01-07        3           0     105                97                8
# 2026-01-08        4           0     115               106                9
# 2026-01-09        5           0     130               118               12
# 2026-01-10        6           1     170               150               20
#
#             active_users  restaurants  promotion  value_count
# date
# 2026-01-01           420           22          0            2
# 2026-01-02           480           23          0            4
# 2026-01-03           620           24          1            3
# 2026-01-04           700           25          1            2
# 2026-01-05           410           22          0            1
# 2026-01-06           450           23          0            2
# 2026-01-07           460           23          0            3
# 2026-01-08           500           24          0            4
# 2026-01-09           550           24          0            4
# 2026-01-10           720           26          1            2

# %%
X = df.drop("orders", axis=1)
y = df[["orders"]]
y

# %%
def split_data(X, y , test_size=0.2, randome_state=42):
    
    random_indeces = np.random.permutation(len(X))
    
    test_set_indeces=  int(len(random_indeces) * test_size)
    
    train_size_indeces= random_indeces[test_set_indeces:]
    test_size_indeces=  random_indeces[:test_set_indeces]

    X_train, X_test= X.iloc[train_size_indeces], X.iloc[test_size_indeces]
    y_train, y_test= y.iloc[train_size_indeces], y.iloc[test_size_indeces]
    
    return X_train, X_test, y_train, y_test
split_data(X,y)
