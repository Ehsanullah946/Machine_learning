# %%
import numpy as np

# %%
dice= np.array([i for i in range(1,7)])

np.random.choice(dice)
# Out:
# np.int64(2)

# %%
rolls= np.array([np.random.choice(dice) for _ in range(20)])
mean= np.mean(rolls)
print(f"the mean : {mean}")
var= round(np.var(rolls))
print(f"the var :{var}")
# Out:
# the mean : 3.2
# the var :3

# %%
n_rolls = 20
print((n_rolls))

first_rolls = np.array([np.random.choice(dice) for _ in range(n_rolls)])
count= 0
for i in range(len(first_rolls)):
   if first_rolls[i] == 3:
      count = count + 1
average =  count / len(first_rolls)
print(average)    
second_rolls = np.array([np.random.choice(dice) for _ in range(n_rolls)])

sum_of_rolls = first_rolls + second_rolls

print(f"mean of first_rolls: {np.mean(first_rolls):.2f}\nvariance of first_rolls: {np.var(first_rolls):.2f}\n")
print(f"mean of second_rolls: {np.mean(second_rolls):.2f}\nvariance of second_rolls: {np.var(second_rolls):.2f}\n")
print(f"mean of sum_of_rolls: {np.mean(sum_of_rolls):.2f}\nvariance of sum_of_rolls: {np.var(sum_of_rolls):.2f}\n")
print(f"covariance between first and second roll:\n{np.cov(first_rolls, second_rolls)}")
# Out:
# 20
# 0.3
# mean of first_rolls: 2.60
# variance of first_rolls: 2.14
#
# mean of second_rolls: 3.40
# variance of second_rolls: 2.84
#
# mean of sum_of_rolls: 6.00
# variance of sum_of_rolls: 4.20
#
# covariance between first and second roll:
# [[ 2.25263158 -0.41052632]
#  [-0.41052632  2.98947368]]

# %%
random = np.array([np.random.randint(1,7) for i in range(20)])
average = np.mean(random)
print((random))
# Out:
# [2 4 3 2 3 4 1 6 2 4 3 4 1 3 2 4 3 6 2 6]
