# %%
class A:
    def __init__(self):
        self.value= 3
        self._value=4
        self.__value=8
my_object= A()
print(my_object.__dict__)
print(my_object._A__value)
# Out:
# {'value': 3, '_value': 4, '_A__value': 8}
# 8
