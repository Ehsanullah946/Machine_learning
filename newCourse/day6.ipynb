# %%
import numpy as np

# %%
# type hinting 


x=2

type(x)


x: int= 3

def typehinging(x: int, y: int) ->int:
    print(f"{x} and {y}")
    
    
def typehinging(x: int, y: int) ->None:
    print(f"{x} and {y}")
    
from typing import List, Dict, Set, Callable, Sequence

x: List[List[int]] = [[2,3,4],[43,5,56]]
   
print(x)   

y: Dict[str, int] = {"a": 2}
print(y)    


def myfunction(x:int, y:float) -> str:
    return "hello"


def myfunction2(func: Callable[[int, float], str]) -> None:
    pass
# Out:
# [[2, 3, 4], [43, 5, 56]]
# {'a': 2}

# %%
def my_function(x: int,y: int) -> None:
    print(f"{x} + {y} = {x+y}")
my_function(2,6)
