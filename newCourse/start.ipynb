# %%
salse_record= {
    "price": 32,
    "num_items":4,
    "person": "Ehsanullah"
}
salse_statement= '{} bought {} itmes from at a price of {} each for a total of {}'
print(salse_statement.format(salse_record["person"],
                             salse_record["num_items"],
                             salse_record["price"],
                             salse_record["num_items"]*salse_record["price"]))
# Out:
# Ehsanullah bought 4 itmes from at a price of 32 each for a total of 128

# %%
import csv


with open("mizban_orders.csv") as csvFile:
    mpg= list(csv.DictReader(csvFile))
    
mpg [:3]
# Out:
# [{'date': '2026-01-01',
#   'weekday': '4',
#   'is_weekend': '0',
#   'orders': '95',
#   'completed_orders': '88',
#   'canceled_orders': '7',
#   'active_users': '420',
#   'restaurants': '22',
#   'promotion': '0'},
#  {'date': '2026-01-02',
#   'weekday': '5',
#   'is_weekend': '0',
#   'orders': '110',
#   'completed_orders': '101',
#   'canceled_orders': '9',
#   'active_users': '480',
#   'restaurants': '23',
#   'promotion': '0'},
#  {'date': '2026-01-03',
#   'weekday': '6',
#   'is_weekend': '1',
#   'orders': '150',
#   'completed_orders': '132',
#   'canceled_orders': '18',
#   'active_users': '620',
#   'restaurants': '24',
#   'promotion': '1'}]

# %%
mpg[0].keys()
# Out:
# dict_keys(['date', 'weekday', 'is_weekend', 'orders', 'completed_orders', 'canceled_orders', 'active_users', 'restaurants', 'promotion'])

# %%
sum(float(d["completed_orders"]) for d in mpg)/ len(mpg)
# Out:
# 131.6949152542373

# %%
sum(float(d["completed_orders"]) for d in mpg) /len(mpg)
# Out:
# 131.6949152542373

# %%
class Person:
    departement= "this is a school"
    name=""
    location=""
    def set_name(self, new_name):
        self.name= new_name
    def set_location(self, new_location):
        self.location= new_location    
    def printLocationAndName(self):
        print(self.name, self.location)

# %%
person= Person()
person.set_location("Kabul")
person.set_name("Ehsanullah")

person.printLocationAndName()
# Out:
# Ehsanullah Kabul

# %%
# def myfunction(x):
#     x = 2
#     print(x)
    
# myfunction(5)  
n=3
def my_function():
   global n
   n +=10
   print(n)
my_function()
print(n)
# Out:
# 13
# 13

# %%
print(type(int))
# Out:
# <class 'type'>

# %%
def constructor(self):
    pass

def catsound(self):
    print("cat mio mio")

# %%
Cat = type("mynewClass",(),{
    "__init__":constructor,
     "sound": catsound 
})
