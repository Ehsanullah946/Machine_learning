# %%
import numpy as np

# %%
alphabet= list(map(lambda  i:i, "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ123456789 *()&^%$#%$#@!?<>,."))
lenght= len(alphabet)
_str= "Hello, world!"
binary_rep= []
for i in _str:
    binary_rep.append(bin(alphabet.index(i)))
binary_rep
# Out:
# ['0b100001',
#  '0b100',
#  '0b1011',
#  '0b1011',
#  '0b1110',
#  '0b1001110',
#  '0b111101',
#  '0b10110',
#  '0b1110',
#  '0b10001',
#  '0b1011',
#  '0b11',
#  '0b1001010']

# %%
def block_creator(binary_code):
    binary_code= binary_code[2:]
    length= len(binary_code)
    for i in range(length,11):
        binary_code= "0" + binary_code
    place = [[0,3],[1,1],[1,2],[1,3],[2,1],[2,2],[2,3],[3,0],[3,1],[3,2],[3,3]]
    block= np.zeros((4,4),np.int8)
    for index,value in enumerate(binary_code):
        row,col= place[index]
        block[row][col]= int(value)                                                  
    if (np.count_nonzero(block[:,1]) + np.count_nonzero(block[:,3])) % 2:
        block[0][1]= 1
    if (np.count_nonzero(block[:,2]) + np.count_nonzero(block[:,3])) % 2:
        block[0][2]= 1    
    if (np.count_nonzero(block[1]) + np.count_nonzero(block[3])) % 2:
        block[1][0]= 1      
    if (np.count_nonzero(block[2]) + np.count_nonzero(block[3])) % 2:
        block[2][0]= 1  
    if np.count_nonzero(block) % 2:
        block[0][0]= 1     
    return block

# %%
binary_str=""
for i in range(len(binary_rep)):
    _list= block_creator(binary_rep[i]).flatten(order="F")
    _list= _list.tolist()
    binary_str += "".join([str(i) for i in _list])
    
binary_str
# Out:
# '0100100000100001011010010000000001111000000100010111100000010001111110011001000001010011100100001111100110100011001000010001001011111001100100001100000000000011011110000001000110001000000100010011101010010000'

# %%
with open("data.txt","w") as fi:
    fi.write(binary_str)
