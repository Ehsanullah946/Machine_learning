# %%
class A:
    def __init__(self, value):
        self.value= value
    def __add__(self, other):
      return  self.value + other.value    

x= A(3)
print(x)
x.value= 44
print(x.value)


y= A(323)
print(x + y)

# %%
class B:
    def __init__(self):
        print("a call to constructor method")
    def __new__(cls):
        print("a call to the new method")
        return object.__new__(cls)  
    def __del__(self):
        print("called distructor method") 
x= A()  
del x
x
