# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../ML/mizban_orders.csv")

# %%
new_colomn= {i:" ".join(i.split("_")).lower() for i in df.columns}
new_colomn2= {i:"_".join(i.split(" ")).lower() for i in df.columns}

df = df.rename(columns=new_colomn2)
df.head(3)
df.astype
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              59 non-null     str
#  1   weekday           59 non-null     int64
#  2   is_weekend        59 non-null     int64
#  3   orders            59 non-null     int64
#  4   completed_orders  59 non-null     int64
#  5   canceled_orders   59 non-null     int64
#  6   active_users      59 non-null     int64
#  7   restaurants       59 non-null     int64
#  8   promotion         59 non-null     int64
# dtypes: int64(8), str(1)
# memory usage: 4.3 KB

# %%
df = df[[col for col in df.columns if col not in ["is_weekend"]]]
type(df)
# Out:
# pandas.DataFrame

# %%
number= 2
if number > 1:
    print("greather then 1")
if number < 3:
    print("this is also true")
else:
    print("this is can not be true")
# Out:
# greather then 1
# this is also true
