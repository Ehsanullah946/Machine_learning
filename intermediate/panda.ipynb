# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../ML/student-mat.csv",delimiter=";")
 
# adding new column
df["newColumn"]= df["famsize"].apply(len)

df.head(4)

# df.iloc[4:12:2, 0:4:1] # it will work perfectly 
# df.iloc[4:12:2]
# df[4:12:2, 0:4:2] # it will not work and do not 
# df.iloc[[3]]
# df.iloc[[1,2,3]]   # return three rows and all columns
# df.loc[[2,3],["age", "famsize"]]
# df.loc[:,"sex"]

# Print out drives_right column as Series
# print(df.loc[:4,"sex"])

# # Print out drives_right column as DataFrame
# print(df.loc[:,["age"]])

# Print out df_per_cap and drives_right as DataFrame
# print(df.loc[:,["famsize","age"]])
# Out:
#     famsize  age
# 0       GT3   18
# 1       GT3   17
# 2       LE3   15
# 3       GT3   15
# 4       GT3   16
# ..      ...  ...
# 390     LE3   20
# 391     LE3   17
# 392     GT3   21
# 393     LE3   18
# 394     LE3   19
#
# [395 rows x 2 columns]

# %%
# filtering pandas dataFrame
# df[np.logical_and(df["age"]>18, df["age"]< 30)]
# is_adult = df["age"] > 18 
# df[is_adult]


# reject_student = df[df.loc[:,"absences"] > 20]
# # reject_student = df[df["absences"] > 20]
# print(reject_student)
 

# import numpy as np
# cpc= cars["cars_per_cap"]
# between= np.logical_and(cpc> 100 , cpc<500)
# # Create medium: observations with cars_per_cap between 100 and 500
# medium = cars[between]

# %%
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]
         
# Build a for loop from scratch
for room in house:
    print(room[0],room[1])
    
    
    
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw', 'austria':'vienna' } 


for key,value in europe.items():
    print(key + " -- " + str(value))
# Out:
# hallway 11.25
# kitchen 18.0
# living room 20.0
# bedroom 10.75
# bathroom 9.5
# spain -- madrid
# france -- paris
# germany -- berlin
# norway -- oslo
# italy -- rome
# poland -- warsaw
# austria -- vienna

# %%
# add new column in our dataset very important 
# for label,row in df.iterrows():
    # print(str(label) + ":" + row["sex"])
    # df.loc[label, "name_length"] = len(row["sex"])

# print(df)


for lab, row in df.iterrows() :
    df.loc[lab, "fjob"] = row["Fjob"].lower()

print(df)

# %%
# random number 
np.random.seed(113)
print(np.random.randint(0,2))
np.random.seed(123)

outcomes= []

for i in range(10):
    coin= np.random.randint(0,2)
    if coin == 0:
        outcomes.append("Head")
    else:
        outcomes.append("tail")
print(outcomes)

# %%
random_walk = [0]


# Complete the ___
for x in range(1000) :
    # Set step: last element in random_walk
    step = random_walk[-1]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        step = step - 1
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# Print random_walk
print(random_walk)

# %%
np.random.seed(123)
final_result= [0]
for x in range(1000):
    tail= [0]
    for i in range(10):
      coin= np.random.randint(0,2)
      tail.append(tail[i] + coin)
    final_result.append(tail[-1])
   
plt.hist(final_result,bins=10) 
plt.show()

# %%
# numpy and matplotlib imported, seed set.

# initialize and populate all_walks
all_walks = []
for i in range(5) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to NumPy array: np_aw
np_aw =np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %%
myMatrix= np.zeros((4,2),np.int8)

my_new_matrix=myMatrix.reshape((2,4))
my_new_matrix
# Out:
# array([[0, 0, 0, 0],
#        [0, 0, 0, 0]], dtype=int8)
