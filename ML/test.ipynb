# %%
import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
# import sklearn
# from sklearn.model_selection import train_test_split
# from sklearn import linear_model

# %%
df = pd.read_csv("student-mat.csv", sep=';')
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='str')

# %%
df = df[["age","freetime","absences","goout","G1","G2","G3"]]

# %%
prediction= "G3"
x= np.array(df.drop([prediction], axis=1))
y= np.array(df[prediction])

# %%
x_train , x_test, y_train, y_test = train_test_split(x,y, test_size=0.1, random_state=123)
model = linear_model.LinearRegression()
model.fit(x_train, y_train)
score= model.score(x_test, y_test)
print(score)
# Out:
# 0.8833294240250273

# %%
model.coef_
# Out:
# array([-0.20498547,  0.11868484,  0.04266907,  0.05082228,  0.166857  ,
#         0.96316553])

# %%
model.intercept_
# Out:
# np.float64(0.8712299252985165)

# %%
model.predict([x_test[0]])
# Out:
# array([7.51328071])

# %%
prediction= model.predict(x_test)
plt.figure(figsize=(15,5))
plt.plot(prediction, label="pred")
plt.plot(y_test, label="real")
plt.grid()
plt.legend()
plt.show()

# %%
prediction = model.predict(x_test)
for i in range(len(prediction)):
    print(f"prediction:{prediction[i]}\t real={y_test[i]}")
# Out:
# prediction:13.097965001211731	 real=11
# prediction:9.19104412798243	 real=10
# prediction:11.445119899308215	 real=11
# prediction:10.294712969098333	 real=10
# prediction:5.875445263628373	 real=0
# prediction:10.560887861792695	 real=10
# prediction:12.975296645017313	 real=12
# prediction:8.676593402662995	 real=9
# prediction:3.887278086752866	 real=6
# prediction:8.32167063235198	 real=10
# prediction:9.435921215068449	 real=10
# prediction:-1.2698784593556327	 real=0
# prediction:16.398976694867926	 real=15
# prediction:10.389969398536564	 real=10
# prediction:14.735414165770242	 real=15
# prediction:14.022432468096506	 real=15
# prediction:6.194272465815776	 real=9
# prediction:13.442102693388017	 real=13
# prediction:8.048151388826518	 real=8
# prediction:10.131876536594508	 real=11
# prediction:10.267365257497326	 real=12
# prediction:4.212150395961162	 real=5
# prediction:9.710573274691404	 real=10
# prediction:12.905078107605187	 real=13
# prediction:12.297463880886323	 real=13
# prediction:7.6090208112639015	 real=9
# prediction:-1.2191957205341568	 real=0
# prediction:12.192093272026787	 real=13
# prediction:15.136615971724481	 real=15
# prediction:12.91218799607053	 real=14
# prediction:8.098161046594452	 real=8
# prediction:16.512832297791363	 real=18
# prediction:15.655677556254195	 real=15
# prediction:16.14739582053283	 real=16
# prediction:8.577128779445369	 real=9
# prediction:10.644156015775321	 real=8
# prediction:9.235354274547285	 real=9
# prediction:10.092109488558242	 real=10
# prediction:12.377405852893396	 real=13
# prediction:11.164624815753271	 real=11
