# %%
import random
import numpy as np


normal = [random.randint(100, 500) for _ in range(1000)]
anomaly = [random.randint(5000, 10000) for _ in range(20)]

print(len(normal))

# %%
my_rand_number= [np.random.randint(100,500) for i in range(1000)]
my_rand_number
