# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
df = pd.read_csv("prod_mizban.orders.csv", sep=',')

# %%
real_data= pd.read_csv("mizban_orders.csv")

# %%
real_data.head()
# Out:
#          date  weekday  is_weekend  orders  completed_orders  canceled_orders  \
# 0  2026-01-01        4           0      95                88                7
# 1  2026-01-02        5           0     110               101                9
# 2  2026-01-03        6           1     150               132               18
# 3  2026-01-04        7           1     165               145               20
# 4  2026-01-05        1           0      90                83                7
#
#    active_users  restaurants  promotion
# 0           420           22          0
# 1           480           23          0
# 2           620           24          1
# 3           700           25          1
# 4           410           22          0

# %%
df.tail(60)
# Out:
#     orders  completed_orders  canceled_orders        date  active_users  \
# 0       11                 4                7  2026-02-19             9
# 1        6                 4                2  2026-02-20             5
# 2        7                 3                4  2026-02-21             4
# 3       10                 1                9  2026-02-22             4
# 4       37                11               26  2026-02-23            12
# 5        8                 4                4  2026-02-24             6
# 6       12                 4                8  2026-02-25             6
# 7       22                 8               14  2026-02-26            10
# 8        5                 3                2  2026-02-27             2
# 9        3                 0                3  2026-02-28             3
# 10       5                 1                4  2026-03-01             4
# 11       7                 2                5  2026-03-02             5
# ...
